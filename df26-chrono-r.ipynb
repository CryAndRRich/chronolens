# %%
import os
import warnings
import random
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import GradScaler, autocast
from gensim.models import Word2Vec

# %%
def set_seed(seed):
    os.environ["PYTHONHASHSEED"] = str(seed)
    os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
    
    warnings.filterwarnings("ignore")
    random.seed(seed)
    np.random.seed(seed)
    
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) 
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(False)
    
    print(f"Random seed set to {seed}")

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2 ** 32
    random.seed(worker_seed)
    np.random.seed(worker_seed)

# %%
RANDOM_SEED = 42
set_seed(RANDOM_SEED)

data_generator = torch.Generator()
data_generator.manual_seed(RANDOM_SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
# Out:
# Random seed set to 42
# Device: cuda

# %%
INPUT_ROOT = "/kaggle/input/datasets/minhnguyn132/input-df26-v3"
WORK_DIR = "/kaggle/working"

X_TRAIN = f"{INPUT_ROOT}/X_train.csv"
X_VAL = f"{INPUT_ROOT}/X_val.csv"
X_TEST = f"{INPUT_ROOT}/X_test.csv"
Y_TRAIN = f"{INPUT_ROOT}/Y_train.csv"
Y_VAL = f"{INPUT_ROOT}/Y_val.csv"

SUBMISSION_FILE = f"{WORK_DIR}/submission.csv"
CHECKPOINT_FILE = f"{WORK_DIR}/best_model.pth"

# %%
SEQ_LENGTH = 66
FEATURE_COLS = [f"feature_{i}" for i in range(1, SEQ_LENGTH + 1)]

ATTRIBUTE_LIST = [1, 2, 3, 4, 5, 6]
ATTRIBUTE_COLS = ["start_year", "attr_1", "attr_2", "attr_3",
                  "end_year", "attr_4", "attr_5", "attr_6"]

EMBEDDING_DIM = 256
DILATIONS = [1, 2, 4, 8]
DROPOUT_RATE = 0.3
HEADS = 4
WINDOW_SIZE = 3

BATCH_SIZE = 1024
NUM_EPOCHS = 100
EARLY_STOPPING = 15
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-2
MAX_LR = 1e-3
PCT_START = 0.2
FINAL_DIV_FACTOR = 10000.0

M_LIST_LOSS = [1.0, 12.0, 31.0, 99.0, 1.0, 12.0, 31.0, 99.0]
M_LIST_METRIC = [12.0, 31.0, 99.0, 12.0, 31.0, 99.0]
W_LIST_VALS = [1.0, 1.0, 100.0, 1.0, 1.0, 100.0]

DAYS_IN_MONTH = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
DAYS_MAP = {
    1: 31, 2: 28, 3: 31, 4: 30, 5: 31, 6: 30,
    7: 31, 8: 31, 9: 30, 10: 31, 11: 30, 12: 31
}

# %%
def drop_duplicates_custom(x_df, y_df, feature_cols=FEATURE_COLS, name="Train"):
    len_before = len(x_df)
    keep_idx = x_df.drop_duplicates(subset=feature_cols, keep="first").index
    
    x_df = x_df.loc[keep_idx].reset_index(drop=True)
    y_df = y_df.loc[keep_idx].reset_index(drop=True)
    
    print(f" - Loại bỏ {len_before - len(x_df)} hàng trùng lặp trong {name}")
    return x_df, y_df

# %%
def drop_overlap_train_val(x_train, y_train, x_val, feature_cols=FEATURE_COLS):
    len_before = len(x_train)
    
    val_features_unique = x_val[feature_cols].drop_duplicates().copy()
    val_features_unique["is_in_val"] = True
    
    x_train["old_idx"] = x_train.index
    train_merged = x_train.merge(val_features_unique, on=feature_cols, how="left")
    
    clean_train_idx = train_merged[train_merged["is_in_val"].isna()]["old_idx"]
    
    x_train = x_train.loc[clean_train_idx].drop(columns=["old_idx"]).reset_index(drop=True)
    y_train = y_train.loc[clean_train_idx].reset_index(drop=True)
    
    print(f" - Loại bỏ {len_before - len(x_train)} chuỗi Train bị trùng với Val")
    return x_train, y_train

# %%
def validate_and_clean_dates(x_df, y_df, days_map=DAYS_MAP, name="Train"):
    max_days_start = y_df["attr_1"].map(days_map)
    invalid_start_day_mask = y_df["attr_2"] > max_days_start

    max_days_end = y_df["attr_4"].map(days_map)
    invalid_end_day_mask = y_df["attr_5"] > max_days_end

    all_invalid_mask = invalid_start_day_mask | invalid_end_day_mask
    invalid_count = all_invalid_mask.sum()

    if invalid_count > 0:
        print(f" - Phát hiện {invalid_count} hàng có lỗi ngày trong {name}")
        
        y_df.loc[invalid_start_day_mask, "attr_2"] = max_days_start[invalid_start_day_mask]
        y_df.loc[invalid_end_day_mask, "attr_5"] = max_days_end[invalid_end_day_mask]
        
    else:
        print(f" - Không có lỗi ngày tháng trong {name}")

    return x_df, y_df

# %%
def get_vocab_size(x_train, x_val, x_test, feature_cols=FEATURE_COLS):
    all_x_data = pd.concat([x_train[feature_cols], x_val[feature_cols]], axis=0)
    unique_ids = pd.unique(all_x_data.values.ravel())
    unique_ids = [uid for uid in unique_ids if not pd.isna(uid) and uid != 0]
    
    id_to_index = {0: 0, "UNK": 1}
    for idx, raw_id in enumerate(sorted(unique_ids), start=2):
        id_to_index[raw_id] = idx
        
    vocab_size = max(id_to_index.values()) + 1
    print(f" - Kích thước từ điển {vocab_size} (PAD=0, UNK=1)")

    map_func = np.vectorize(lambda x: id_to_index.get(x, 1))
    
    for df in [x_train, x_val, x_test]:
        df.loc[:, feature_cols] = map_func(df[feature_cols].values)

    return x_train, x_val, x_test, vocab_size

# %%
def manual_augment(x_train, y_train, x_test, feature_cols):
    train_lengths = (x_train[feature_cols] != 0).sum(axis=1)
    test_lengths = (x_test[feature_cols] != 0).sum(axis=1)
    
    train_counts = train_lengths.value_counts()
    test_counts = test_lengths.value_counts()
    
    augmented_x = [x_train]
    augmented_y = [y_train]
    
    for length, c_test in test_counts.items():
        c_train = train_counts.get(length, 0)

        if c_test > c_train:
            if c_train == 0:
                multiplier = 10
            else:
                multiplier = min(c_test / c_train, 10)
            
            n_repeats = int(multiplier) - 1
            
            if n_repeats > 0:
                mask = (train_lengths == length)
                x_to_dup = x_train[mask]
                y_to_dup = y_train[mask]
                
                if len(x_to_dup) > 0:
                    for _ in range(n_repeats):
                        augmented_x.append(x_to_dup)
                        augmented_y.append(y_to_dup)
    x_train_new = pd.concat(augmented_x, ignore_index=True)
    y_train_new = pd.concat(augmented_y, ignore_index=True)
    
    idx = np.random.permutation(len(x_train_new))
    x_train_new = x_train_new.iloc[idx].reset_index(drop=True)
    y_train_new = y_train_new.iloc[idx].reset_index(drop=True)
    
    print(f" - Train tăng từ {len(x_train)} lên {len(x_train_new)} mẫu")
    return x_train_new, y_train_new

# %%
def process_data(x_train, y_train, x_val, y_val, x_test,
                 feature_cols=FEATURE_COLS,
                 attr_cols=ATTRIBUTE_COLS,
                 days_map=DAYS_MAP):
    
    for df in [x_train, x_val, x_test]:
        df[feature_cols] = df[feature_cols].fillna(0).astype(np.int64)
    for df in [y_train, y_val]:
        df["start_year"] = 0
        df["end_year"] = (df["attr_4"] < df["attr_1"]).astype(np.int64)
        df[attr_cols] = df[attr_cols].fillna(0).astype(np.float32)

    print("Xử lý trùng lặp nội bộ...")
    x_train, y_train = drop_duplicates_custom(x_train, y_train, feature_cols, "Train")
    x_val, y_val = drop_duplicates_custom(x_val, y_val, feature_cols, "Val")
    
    print("Xử lý trùng lặp giữa Train và Val...")
    x_train, y_train = drop_overlap_train_val(x_train, y_train, x_val, feature_cols)

    print("Xử lý lỗi ngày tháng...")
    x_train, y_train = validate_and_clean_dates(x_train, y_train, days_map, "Train")
    x_val, y_val = validate_and_clean_dates(x_val, y_val, days_map, "Val")

    print("Xây dựng từ điển và map index...")
    x_train, x_val, x_test, vocab_size = get_vocab_size(x_train, x_val, x_test, feature_cols)

    print("Sinh thủ công thêm chuỗi...")
    x_train, y_train = manual_augment(x_train, y_train, x_test, feature_cols)
    
    return x_train, y_train, x_val, y_val, x_test, vocab_size

# %%
class UserBehaviorDataset(Dataset):
    def __init__(self, x_df, y_df=None, 
                 feature_cols=FEATURE_COLS, attr_cols=ATTRIBUTE_COLS, augment=False):
        self.x_data = x_df[feature_cols].values
        self.augment = augment 
        
        self.has_labels = y_df is not None
        if self.has_labels:
            self.y_data = y_df[attr_cols].values

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x_tensor = torch.tensor(self.x_data[idx], dtype=torch.long)
        
        if self.augment:
            actions = x_tensor[x_tensor != 0]
            n_actions = len(actions)
            total_slots = len(x_tensor) 
            
            if torch.rand(1).item() < 0.5:
                n_mask = (n_actions // 10) + 1
                possible_indices = torch.arange(n_actions - 1)
                
                if len(possible_indices) >= n_mask:
                    mask_indices = possible_indices[torch.randperm(len(possible_indices))[:n_mask]]
                    actions[mask_indices] = 0
            
            if torch.rand(1).item() < 0.5:
                new_indices = torch.randperm(total_slots)[:n_actions].sort()[0]
                dilated_x = torch.zeros_like(x_tensor)
                dilated_x[new_indices] = actions
                x_tensor = dilated_x
            else:
                new_x = torch.zeros_like(x_tensor)
                new_x[:n_actions] = actions
                x_tensor = new_x

        if self.has_labels:
            y_tensor = torch.tensor(self.y_data[idx], dtype=torch.float32)
            return x_tensor, y_tensor
        
        return x_tensor

# %%
def create_dataloaders(x_train, y_train, x_val, y_val, x_test, 
                       batch_size=BATCH_SIZE,
                       num_workers=2,
                       seed_worker=seed_worker,
                       data_generator=data_generator):
    
    train_dataset = UserBehaviorDataset(x_train, y_train, augment=True)
    val_dataset = UserBehaviorDataset(x_val, y_val, augment=False)
    test_dataset = UserBehaviorDataset(x_test, None, augment=False)

    train_loader = DataLoader(
        train_dataset, 
        batch_size=batch_size, 
        shuffle=True, 
        num_workers=num_workers, 
        worker_init_fn=seed_worker, 
        generator=data_generator,
        pin_memory=True, 
        drop_last=True, 
        persistent_workers=True  
    )
    
    val_loader = DataLoader(
        val_dataset, 
        batch_size=batch_size, 
        shuffle=False, 
        num_workers=num_workers,           
        pin_memory=True,
        persistent_workers=False 
    )
    
    test_loader = DataLoader(
        test_dataset, 
        batch_size=batch_size, 
        shuffle=False, 
        num_workers=num_workers,
        pin_memory=True
    )
    
    return train_loader, val_loader, test_loader

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class AttentionPooling1D(nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.attn = nn.Linear(in_features, 1)

    def forward(self, x, mask):
        scores = self.attn(x) 
        if mask is not None:
            fill_value = torch.finfo(scores.dtype).min
            scores = scores.masked_fill(~mask.unsqueeze(-1), fill_value)
        attn_weights = F.softmax(scores, dim=1)
        return torch.sum(x * attn_weights, dim=1)

class CascadeRegressionHead(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.head_start = nn.Sequential(
            nn.Linear(d_model, 64), nn.GELU(), nn.Linear(64, 3)
        )
        self.start_proj = nn.Sequential(
            nn.Linear(3, 16), nn.GELU(), nn.Linear(16, 32)
        )
        
        self.head_factory = nn.Sequential(
            nn.Linear(d_model + 32, 128), nn.LayerNorm(128), nn.GELU(), 
            nn.Dropout(0.2), nn.Linear(128, 64), nn.GELU(), nn.Linear(64, 2)
        )
        
        self.head_end = nn.Sequential(
            nn.Linear(d_model + 32, 64), nn.GELU(), nn.Linear(64, 3)
        )

    def forward(self, x):
        start_preds = self.head_start(x)  
        start_context = self.start_proj(start_preds)
        
        factory_in = torch.cat([x, start_context], dim=-1)
        factory_preds = self.head_factory(factory_in) 
        
        end_in = torch.cat([x, start_context], dim=-1)
        end_preds = self.head_end(end_in)    
        
        s_year = torch.sigmoid(start_preds[:, 0])
        e_year = torch.sigmoid(end_preds[:, 0])
        s_month = 1.0 + 11.0 * torch.sigmoid(start_preds[:, 1])
        e_month = 1.0 + 11.0 * torch.sigmoid(end_preds[:, 1])
        s_day = 1.0 + 30.0 * torch.sigmoid(start_preds[:, 2])
        e_day = 1.0 + 30.0 * torch.sigmoid(end_preds[:, 2])
        s_power = 99.0 * torch.sigmoid(factory_preds[:, 0])
        e_power = 99.0 * torch.sigmoid(factory_preds[:, 1])
        
        return [s_year, s_month, s_day, s_power, e_year, e_month, e_day, e_power]

class GCE_FusionLayer(nn.Module):
    def __init__(self, vocab_size, d_model, dropout=0.2):
        super().__init__()
        self.global_memory = nn.Embedding(vocab_size, d_model, padding_idx=0)
        self.fusion_gate = nn.Linear(d_model * 2, d_model)
        self.transform = nn.Linear(d_model, d_model)
        self.dropout = nn.Dropout(dropout)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, local_features, input_ids):
        global_features = self.global_memory(input_ids) 
        concat_features = torch.cat([local_features, global_features], dim=-1)
        gate_score = torch.sigmoid(self.fusion_gate(concat_features)) 
        fused_features = gate_score * local_features + (1.0 - gate_score) * global_features
        out = self.dropout(F.gelu(self.transform(fused_features)))
        return self.norm(local_features + out) 

class ResidualBiGRUBlock(nn.Module):
    def __init__(self, d_model, dropout=0.2):
        super().__init__()
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        res = x
        out, _ = self.gru(x)
        out = self.dropout(out)
        return self.norm(res + out)

class MultiScaleConv1D(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        dim = d_model // 4
        self.conv1 = nn.Conv1d(d_model, dim, kernel_size=1)
        self.conv3 = nn.Conv1d(d_model, dim, kernel_size=3, padding=1)
        self.conv5 = nn.Conv1d(d_model, dim, kernel_size=5, padding=2)
        # Bắt chước dilation của GNN
        self.conv_dilated = nn.Conv1d(d_model, dim, kernel_size=3, padding=2, dilation=2) 
        self.proj = nn.Linear(d_model, d_model)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        x_t = x.transpose(1, 2) 
        c1 = F.gelu(self.conv1(x_t))
        c3 = F.gelu(self.conv3(x_t))
        c5 = F.gelu(self.conv5(x_t))
        cd = F.gelu(self.conv_dilated(x_t))
        
        out = torch.cat([c1, c3, c5, cd], dim=1).transpose(1, 2)
        return self.norm(x + self.proj(out))

class AdvancedTARNet(nn.Module):
    def __init__(self, vocab_size, seq_length=66, d_model=256, dropout=0.3):
        super().__init__()
        
        self.embedding = nn.Embedding(vocab_size, d_model, padding_idx=0)
        self.pos_embedding = nn.Embedding(seq_length, d_model)
        
        self.multi_scale_conv = MultiScaleConv1D(d_model)
        self.conv_dropout = nn.Dropout(dropout)
        
        self.rnn_blocks = nn.ModuleList([
            ResidualBiGRUBlock(d_model, dropout) for _ in range(2)
        ])
        
        self.gce_fusion = GCE_FusionLayer(vocab_size, d_model, dropout)
        
        self.transformer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=4, dim_feedforward=d_model*2, 
            dropout=dropout, batch_first=True, activation='gelu'
        )
        
        self.attn_pool = AttentionPooling1D(d_model)
        self.dropout = nn.Dropout(dropout)
        self.cascade_head = CascadeRegressionHead(d_model)

        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.xavier_normal_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.Embedding):
            nn.init.normal_(m.weight, mean=0.0, std=0.02)
        elif isinstance(m, nn.GRU):
            for name, param in m.named_parameters():
                if 'weight_ih' in name:
                    nn.init.xavier_uniform_(param.data)
                elif 'weight_hh' in name:
                    nn.init.orthogonal_(param.data)

    def forward(self, x):
        B, L = x.size()
        mask = (x != 0)
        mask_float = mask.unsqueeze(-1).float()
        
        pos = torch.arange(L, device=x.device).unsqueeze(0).expand(B, L)
        h_emb = (self.embedding(x) + self.pos_embedding(pos)) * mask_float
        
        h_conv = self.multi_scale_conv(h_emb)
        h_conv = self.conv_dropout(h_conv) * mask_float
        
        h_rnn = h_conv
        for rnn_block in self.rnn_blocks:
            h_rnn = rnn_block(h_rnn) * mask_float
            
        h_fuse = self.gce_fusion(h_rnn, x) * mask_float
        
        h_attn = self.transformer(h_fuse, src_key_padding_mask=~mask)
        
        h_final = h_emb + h_conv + h_attn
        
        x_pool = self.dropout(self.attn_pool(h_final, mask))
        return self.cascade_head(x_pool)

# %%
class HybridThresholdLoss(nn.Module):
    def __init__(self, device, start_threshold=0.01, end_threshold=0.05):
        super().__init__()
        self.device = device
        self.M = torch.tensor(M_LIST_LOSS, device=device).view(1, -1)
        
        self.start_w = torch.tensor([100.0, 100.0, 100.0, 1.0, 100.0, 100.0, 100.0, 1.0], device=device).view(1, -1)
        
        self.end_w = torch.tensor([0.0, 1.0, 1.0, 100.0, 0.0, 1.0, 1.0, 100.0], device=device).view(1, -1)
        self.w = self.start_w.clone()
        
        self.start_delta = start_threshold
        self.end_delta = end_threshold
        self.delta = start_threshold 

    def update_params(self, current_epoch, total_epochs=10):
        progress = current_epoch / total_epochs
        
        self.w = self.start_w + (self.end_w - self.start_w) * progress
        
        current_delta = self.start_delta + ((self.end_delta - self.start_delta) * progress)
        self.delta = current_delta

        return self.w[0, 0].item(), self.w[0, 1].item(), self.w[0, 3].item()
        
    def forward(self, preds_list, targets):
        if isinstance(preds_list, list):
            preds = torch.stack(preds_list, dim=1)
        else:
            preds = preds_list

        abs_err = torch.abs(targets.float() - preds) / self.M
        quad = torch.clamp(abs_err, max=self.delta)
        lin = abs_err - quad

        hybrid_loss = self.w * (0.5 * (quad ** 2) + self.delta * lin)
        return torch.mean(torch.sum(hybrid_loss, dim=1))

# %%
def train_model(model, 
                train_loader, 
                val_loader, 
                y_val_orig, 
                optimizer, 
                scheduler, 
                device=DEVICE):
    
    loss_fn = HybridThresholdLoss(device)
    best_score = float("inf")
    best_epoch = 0 
    scaler = GradScaler()
    early_count = 0
    
    for epoch in range(NUM_EPOCHS):
        if epoch <= 10:
            loss_fn.update_params(epoch)
        
        model.train()
        train_loss = 0.0
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad(set_to_none=True)
            
            with autocast():
                preds = model(x)
                
            loss = loss_fn(preds, y.float())
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            train_loss += loss.item()
            
        avg_train_loss = train_loss / len(train_loader)
        
        y_pred_val = run_inference(model, val_loader, device)
        val_score = evaluate_wmse(y_val_orig, y_pred_val)
        
        print(f"Epoch {epoch + 1:02d}/{NUM_EPOCHS} | LR: {optimizer.param_groups[0]['lr']:.6f} | "
              f"Train Loss: {avg_train_loss:.4f} | Val Score: {val_score:.4f}")
        
        if val_score < best_score:
            best_score = val_score
            best_epoch = epoch + 1 
            torch.save(model.state_dict(), CHECKPOINT_FILE)
            print(f"  => Mô hình tốt nhất! (Val Score: {val_score:.4f})")
            early_count = 0
        else:
            early_count += 1
            print(f"  => Mô hình không cải thiện ({early_count}/{EARLY_STOPPING})")
            if early_count >= EARLY_STOPPING:
                print(f"  => Dừng sớm tại Epoch {epoch + 1} (Best Score: {best_score:.4f})")
                break
                
    return best_epoch

# %%
def post_process_predictions(preds_tensor):
    preds = preds_tensor.clone()
    preds = torch.round(preds)
    
    preds[:, [0, 3]] = (preds[:, [0, 3]] - 1) % 12 + 1
    preds[:, [0, 3]] = torch.clamp(preds[:, [0, 3]], 1, 12)

    days_in_month_t = torch.tensor(DAYS_IN_MONTH, device=preds.device, dtype=preds.dtype)
    
    for col_idx, month_idx in [(1, 0), (4, 3)]:
        m_indices = (preds[:, month_idx].long() - 1).clamp(0, 11)
        max_days = days_in_month_t[m_indices]
        
        preds[:, col_idx] = torch.clamp(preds[:, col_idx], min=1)
        preds[:, col_idx] = torch.min(preds[:, col_idx], max_days)

    preds[:, [2, 5]] = torch.clamp(preds[:, [2, 5]], 0, 99)
    
    return preds

def run_inference(model, loader, device=DEVICE):
    model.eval()
    all_preds = []
    with torch.no_grad():
        for batch in loader:
            x = batch[0] if isinstance(batch, (list, tuple)) else batch
            outputs = model(x.to(device))
            all_preds.append(torch.stack(outputs, dim=1) if isinstance(outputs, list) else outputs)
    
    all_preds = torch.cat(all_preds, dim=0)[:, [1, 2, 3, 5, 6, 7]]
    return post_process_predictions(all_preds).cpu().numpy()

def evaluate_wmse(y_true, y_pred):
    M, W = np.array(M_LIST_METRIC), np.array(W_LIST_VALS)
    return np.mean(np.sum(W * np.power((y_true - y_pred) / M, 2), axis=1))

# %%
x_train = pd.read_csv(X_TRAIN)
y_train = pd.read_csv(Y_TRAIN)
x_val = pd.read_csv(X_VAL)
y_val = pd.read_csv(Y_VAL)
x_test = pd.read_csv(X_TEST)

x_train, y_train, x_val, y_val, x_test, VOCAB_SIZE = process_data(
    x_train, y_train, x_val, y_val, x_test
)

y_val_orig = (y_val[ATTRIBUTE_COLS].values)[:, [1, 2, 3, 5, 6, 7]] 

train_loader, val_loader, test_loader = create_dataloaders(
    x_train, y_train, x_val, y_val, x_test
)
# Out:
# Xử lý trùng lặp nội bộ...
#  - Loại bỏ 99 hàng trùng lặp trong Train
#  - Loại bỏ 110 hàng trùng lặp trong Val
# Xử lý trùng lặp giữa Train và Val...
#  - Loại bỏ 187 chuỗi Train bị trùng với Val
# Xử lý lỗi ngày tháng...
#  - Phát hiện 1010 hàng có lỗi ngày trong Train
#  - Phát hiện 749 hàng có lỗi ngày trong Val
# Xây dựng từ điển và map index...
#  - Kích thước từ điển 934 (PAD=0, UNK=1)
# Sinh thủ công thêm chuỗi...
#  - Train tăng từ 54714 lên 105245 mẫu

# %%
model = AdvancedTARNet(vocab_size=VOCAB_SIZE).to(DEVICE)
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=MAX_LR, epochs=NUM_EPOCHS, 
    steps_per_epoch=len(train_loader), pct_start=PCT_START, final_div_factor=FINAL_DIV_FACTOR
)

print("--- BẮT ĐẦU DÒ TÌM BEST EPOCH (PHASE 1) ---")
best_epoch = train_model(model, train_loader, val_loader, y_val_orig, optimizer, scheduler)
print(f"\n=> ĐÃ KHÓA ĐƯỢC BEST EPOCH TẠI VÒNG: {best_epoch}")


model.load_state_dict(torch.load(CHECKPOINT_FILE, map_location=DEVICE))
model.eval()
val_preds = run_inference(model, val_loader)

def wmape(y_t, y_p):
    sum_abs_error = np.sum(np.abs(y_t - y_p))
    sum_abs_true = np.sum(np.abs(y_t))
    return (sum_abs_error / (sum_abs_true + 1e-8)) * 100

print("\n" + "=" * 76)
print(f"{'THUỘC TÍNH':<12} | {'MAE':<10} | {'MSE':<12} | {'RMSE':<10} | {'WMAPE':<10}")
print("-" * 76)

for i, attr in enumerate(ATTRIBUTE_LIST):
    y_t = y_val_orig[:, i]
    y_p = val_preds[:, i]
    
    mae = np.mean(np.abs(y_t - y_p))
    mse = np.mean(np.square(y_t - y_p))
    rmse = np.sqrt(mse)
    wmape_val = wmape(y_t, y_p)
    
    print(f"Attr {attr:<7} | {mae:<10.4f} | {mse:<12.4f} | {rmse:<10.4f} | {wmape_val:<10.4f}")

print("=" * 76)

overall_mae = np.mean(np.abs(y_val_orig - val_preds))
overall_mse = np.mean(np.square(y_val_orig - val_preds))
overall_rmse = np.sqrt(overall_mse)
overall_wmape = wmape(y_val_orig, val_preds)
final_wmse = evaluate_wmse(y_val_orig, val_preds)

print(f"{'MAE':<15}: {overall_mae:.4f}")
print(f"{'MSE':<15}: {overall_mse:.4f}")
print(f"{'RMSE':<15}: {overall_rmse:.4f}")
print(f"{'WMAPE':<15}: {overall_wmape:.4f}")
print(f"{'WMSE':<15}: {final_wmse:.4f}")
print("=" * 76)
# Out:
# --- BẮT ĐẦU DÒ TÌM BEST EPOCH (PHASE 1) ---
# Epoch 01/100 | LR: 0.000046 | Train Loss: 1.5592 | Val Score: 17.3675
#   => Mô hình tốt nhất! (Val Score: 17.3675)
# Epoch 02/100 | LR: 0.000064 | Train Loss: 1.7866 | Val Score: 17.1965
#   => Mô hình tốt nhất! (Val Score: 17.1965)
# Epoch 03/100 | LR: 0.000092 | Train Loss: 1.9590 | Val Score: 16.9935
#   => Mô hình tốt nhất! (Val Score: 16.9935)
# Epoch 04/100 | LR: 0.000132 | Train Loss: 2.0491 | Val Score: 16.9297
#   => Mô hình tốt nhất! (Val Score: 16.9297)
# Epoch 05/100 | LR: 0.000181 | Train Loss: 1.8961 | Val Score: 16.8245
#   => Mô hình tốt nhất! (Val Score: 16.8245)
# Epoch 06/100 | LR: 0.000238 | Train Loss: 1.7287 | Val Score: 16.7144
#   => Mô hình tốt nhất! (Val Score: 16.7144)
# Epoch 07/100 | LR: 0.000302 | Train Loss: 1.6832 | Val Score: 13.2454
#   => Mô hình tốt nhất! (Val Score: 13.2454)
# Epoch 08/100 | LR: 0.000372 | Train Loss: 1.4581 | Val Score: 4.0075
#   => Mô hình tốt nhất! (Val Score: 4.0075)
# Epoch 09/100 | LR: 0.000445 | Train Loss: 1.0090 | Val Score: 2.5501
#   => Mô hình tốt nhất! (Val Score: 2.5501)
# Epoch 10/100 | LR: 0.000520 | Train Loss: 0.7652 | Val Score: 1.8814
#   => Mô hình tốt nhất! (Val Score: 1.8814)
# Epoch 11/100 | LR: 0.000595 | Train Loss: 0.5006 | Val Score: 1.6692
#   => Mô hình tốt nhất! (Val Score: 1.6692)
# Epoch 12/100 | LR: 0.000669 | Train Loss: 0.4362 | Val Score: 1.6246
#   => Mô hình tốt nhất! (Val Score: 1.6246)
# Epoch 13/100 | LR: 0.000738 | Train Loss: 0.4058 | Val Score: 1.5699
#   => Mô hình tốt nhất! (Val Score: 1.5699)
# Epoch 14/100 | LR: 0.000803 | Train Loss: 0.3776 | Val Score: 1.5564
#   => Mô hình tốt nhất! (Val Score: 1.5564)
# Epoch 15/100 | LR: 0.000860 | Train Loss: 0.3559 | Val Score: 1.3944
#   => Mô hình tốt nhất! (Val Score: 1.3944)
# Epoch 16/100 | LR: 0.000909 | Train Loss: 0.3323 | Val Score: 1.2848
#   => Mô hình tốt nhất! (Val Score: 1.2848)
# Epoch 17/100 | LR: 0.000948 | Train Loss: 0.3112 | Val Score: 1.2173
#   => Mô hình tốt nhất! (Val Score: 1.2173)
# Epoch 18/100 | LR: 0.000977 | Train Loss: 0.2979 | Val Score: 1.1719
#   => Mô hình tốt nhất! (Val Score: 1.1719)
# Epoch 19/100 | LR: 0.000994 | Train Loss: 0.2810 | Val Score: 1.1264
#   => Mô hình tốt nhất! (Val Score: 1.1264)
# Epoch 20/100 | LR: 0.001000 | Train Loss: 0.2690 | Val Score: 1.1165
#   => Mô hình tốt nhất! (Val Score: 1.1165)
# Epoch 21/100 | LR: 0.001000 | Train Loss: 0.2586 | Val Score: 1.1492
#   => Mô hình không cải thiện (1/15)
# Epoch 22/100 | LR: 0.000998 | Train Loss: 0.2493 | Val Score: 1.1593
#   => Mô hình không cải thiện (2/15)
# Epoch 23/100 | LR: 0.000997 | Train Loss: 0.2440 | Val Score: 1.0663
#   => Mô hình tốt nhất! (Val Score: 1.0663)
# Epoch 24/100 | LR: 0.000994 | Train Loss: 0.2319 | Val Score: 1.0568
#   => Mô hình tốt nhất! (Val Score: 1.0568)
# Epoch 25/100 | LR: 0.000990 | Train Loss: 0.2296 | Val Score: 0.9873
#   => Mô hình tốt nhất! (Val Score: 0.9873)
# Epoch 26/100 | LR: 0.000986 | Train Loss: 0.2213 | Val Score: 1.0442
#   => Mô hình không cải thiện (1/15)
# Epoch 27/100 | LR: 0.000981 | Train Loss: 0.2222 | Val Score: 1.0411
#   => Mô hình không cải thiện (2/15)
# Epoch 28/100 | LR: 0.000975 | Train Loss: 0.2167 | Val Score: 1.0398
#   => Mô hình không cải thiện (3/15)
# Epoch 29/100 | LR: 0.000969 | Train Loss: 0.2120 | Val Score: 1.0587
#   => Mô hình không cải thiện (4/15)
# Epoch 30/100 | LR: 0.000962 | Train Loss: 0.2122 | Val Score: 1.0705
#   => Mô hình không cải thiện (5/15)
# Epoch 31/100 | LR: 0.000954 | Train Loss: 0.2099 | Val Score: 1.0888
#   => Mô hình không cải thiện (6/15)
# Epoch 32/100 | LR: 0.000945 | Train Loss: 0.2060 | Val Score: 1.0018
#   => Mô hình không cải thiện (7/15)
# Epoch 33/100 | LR: 0.000936 | Train Loss: 0.2018 | Val Score: 1.0374
#   => Mô hình không cải thiện (8/15)
# Epoch 34/100 | LR: 0.000926 | Train Loss: 0.2035 | Val Score: 1.0895
#   => Mô hình không cải thiện (9/15)
# Epoch 35/100 | LR: 0.000916 | Train Loss: 0.1999 | Val Score: 0.9673
#   => Mô hình tốt nhất! (Val Score: 0.9673)
# Epoch 36/100 | LR: 0.000904 | Train Loss: 0.1956 | Val Score: 1.0844
#   => Mô hình không cải thiện (1/15)
# Epoch 37/100 | LR: 0.000893 | Train Loss: 0.1991 | Val Score: 0.9885
#   => Mô hình không cải thiện (2/15)
# Epoch 38/100 | LR: 0.000880 | Train Loss: 0.1948 | Val Score: 1.0071
#   => Mô hình không cải thiện (3/15)
# Epoch 39/100 | LR: 0.000867 | Train Loss: 0.1902 | Val Score: 0.9697
#   => Mô hình không cải thiện (4/15)
# Epoch 40/100 | LR: 0.000853 | Train Loss: 0.1909 | Val Score: 0.9809
#   => Mô hình không cải thiện (5/15)
# Epoch 41/100 | LR: 0.000839 | Train Loss: 0.1877 | Val Score: 0.9900
#   => Mô hình không cải thiện (6/15)
# Epoch 42/100 | LR: 0.000825 | Train Loss: 0.1863 | Val Score: 0.9860
#   => Mô hình không cải thiện (7/15)
# Epoch 43/100 | LR: 0.000809 | Train Loss: 0.1872 | Val Score: 1.0015
#   => Mô hình không cải thiện (8/15)
# Epoch 44/100 | LR: 0.000794 | Train Loss: 0.1838 | Val Score: 0.9825
#   => Mô hình không cải thiện (9/15)
# Epoch 45/100 | LR: 0.000778 | Train Loss: 0.1846 | Val Score: 0.9492
#   => Mô hình tốt nhất! (Val Score: 0.9492)
# Epoch 46/100 | LR: 0.000761 | Train Loss: 0.1816 | Val Score: 0.9629
#   => Mô hình không cải thiện (1/15)
# Epoch 47/100 | LR: 0.000744 | Train Loss: 0.1810 | Val Score: 0.9705
#   => Mô hình không cải thiện (2/15)
# Epoch 48/100 | LR: 0.000727 | Train Loss: 0.1778 | Val Score: 0.9464
#   => Mô hình tốt nhất! (Val Score: 0.9464)
# Epoch 49/100 | LR: 0.000709 | Train Loss: 0.1780 | Val Score: 0.9798
#   => Mô hình không cải thiện (1/15)
# Epoch 50/100 | LR: 0.000691 | Train Loss: 0.1748 | Val Score: 0.8903
#   => Mô hình tốt nhất! (Val Score: 0.8903)
# Epoch 51/100 | LR: 0.000673 | Train Loss: 0.1738 | Val Score: 0.9124
#   => Mô hình không cải thiện (1/15)
# Epoch 52/100 | LR: 0.000654 | Train Loss: 0.1720 | Val Score: 0.9610
#   => Mô hình không cải thiện (2/15)
# Epoch 53/100 | LR: 0.000636 | Train Loss: 0.1760 | Val Score: 0.9675
#   => Mô hình không cải thiện (3/15)
# Epoch 54/100 | LR: 0.000617 | Train Loss: 0.1757 | Val Score: 0.9481
#   => Mô hình không cải thiện (4/15)
# Epoch 55/100 | LR: 0.000597 | Train Loss: 0.1701 | Val Score: 0.9908
#   => Mô hình không cải thiện (5/15)
# Epoch 56/100 | LR: 0.000578 | Train Loss: 0.1706 | Val Score: 0.9330
#   => Mô hình không cải thiện (6/15)
# Epoch 57/100 | LR: 0.000559 | Train Loss: 0.1703 | Val Score: 0.9989
#   => Mô hình không cải thiện (7/15)
# Epoch 58/100 | LR: 0.000539 | Train Loss: 0.1661 | Val Score: 0.9574
#   => Mô hình không cải thiện (8/15)
# Epoch 59/100 | LR: 0.000519 | Train Loss: 0.1660 | Val Score: 0.9491
#   => Mô hình không cải thiện (9/15)
# Epoch 60/100 | LR: 0.000500 | Train Loss: 0.1680 | Val Score: 0.9236
#   => Mô hình không cải thiện (10/15)
# Epoch 61/100 | LR: 0.000480 | Train Loss: 0.1665 | Val Score: 0.8998
#   => Mô hình không cải thiện (11/15)
# Epoch 62/100 | LR: 0.000461 | Train Loss: 0.1644 | Val Score: 0.9241
#   => Mô hình không cải thiện (12/15)
# Epoch 63/100 | LR: 0.000441 | Train Loss: 0.1640 | Val Score: 0.8820
#   => Mô hình tốt nhất! (Val Score: 0.8820)
# Epoch 64/100 | LR: 0.000422 | Train Loss: 0.1639 | Val Score: 0.9375
#   => Mô hình không cải thiện (1/15)
# Epoch 65/100 | LR: 0.000402 | Train Loss: 0.1627 | Val Score: 0.9042
#   => Mô hình không cải thiện (2/15)
# Epoch 66/100 | LR: 0.000383 | Train Loss: 0.1579 | Val Score: 0.9613
#   => Mô hình không cải thiện (3/15)
# Epoch 67/100 | LR: 0.000364 | Train Loss: 0.1603 | Val Score: 0.9491
#   => Mô hình không cải thiện (4/15)
# Epoch 68/100 | LR: 0.000345 | Train Loss: 0.1610 | Val Score: 0.9160
#   => Mô hình không cải thiện (5/15)
# Epoch 69/100 | LR: 0.000327 | Train Loss: 0.1613 | Val Score: 0.8899
#   => Mô hình không cải thiện (6/15)
# Epoch 70/100 | LR: 0.000308 | Train Loss: 0.1606 | Val Score: 0.8944
#   => Mô hình không cải thiện (7/15)
# Epoch 71/100 | LR: 0.000290 | Train Loss: 0.1584 | Val Score: 0.9122
#   => Mô hình không cải thiện (8/15)
# Epoch 72/100 | LR: 0.000273 | Train Loss: 0.1596 | Val Score: 0.9398
#   => Mô hình không cải thiện (9/15)
# Epoch 73/100 | LR: 0.000256 | Train Loss: 0.1560 | Val Score: 0.8946
#   => Mô hình không cải thiện (10/15)
# Epoch 74/100 | LR: 0.000239 | Train Loss: 0.1547 | Val Score: 0.8985
#   => Mô hình không cải thiện (11/15)
# Epoch 75/100 | LR: 0.000222 | Train Loss: 0.1568 | Val Score: 0.8770
#   => Mô hình tốt nhất! (Val Score: 0.8770)
# Epoch 76/100 | LR: 0.000206 | Train Loss: 0.1547 | Val Score: 0.9130
#   => Mô hình không cải thiện (1/15)
# Epoch 77/100 | LR: 0.000190 | Train Loss: 0.1549 | Val Score: 0.8830
#   => Mô hình không cải thiện (2/15)
# Epoch 78/100 | LR: 0.000175 | Train Loss: 0.1538 | Val Score: 0.9121
#   => Mô hình không cải thiện (3/15)
# Epoch 79/100 | LR: 0.000160 | Train Loss: 0.1538 | Val Score: 0.9057
#   => Mô hình không cải thiện (4/15)
# Epoch 80/100 | LR: 0.000146 | Train Loss: 0.1514 | Val Score: 0.8866
#   => Mô hình không cải thiện (5/15)
# Epoch 81/100 | LR: 0.000133 | Train Loss: 0.1527 | Val Score: 0.8895
#   => Mô hình không cải thiện (6/15)
# Epoch 82/100 | LR: 0.000120 | Train Loss: 0.1523 | Val Score: 0.9012
#   => Mô hình không cải thiện (7/15)
# Epoch 83/100 | LR: 0.000107 | Train Loss: 0.1515 | Val Score: 0.8933
#   => Mô hình không cải thiện (8/15)
# Epoch 84/100 | LR: 0.000095 | Train Loss: 0.1489 | Val Score: 0.8835
#   => Mô hình không cải thiện (9/15)
# Epoch 85/100 | LR: 0.000084 | Train Loss: 0.1504 | Val Score: 0.9018
#   => Mô hình không cải thiện (10/15)
# Epoch 86/100 | LR: 0.000074 | Train Loss: 0.1493 | Val Score: 0.8912
#   => Mô hình không cải thiện (11/15)
# Epoch 87/100 | LR: 0.000064 | Train Loss: 0.1500 | Val Score: 0.8748
#   => Mô hình tốt nhất! (Val Score: 0.8748)
# Epoch 88/100 | LR: 0.000054 | Train Loss: 0.1515 | Val Score: 0.8805
#   => Mô hình không cải thiện (1/15)
# Epoch 89/100 | LR: 0.000046 | Train Loss: 0.1492 | Val Score: 0.8758
#   => Mô hình không cải thiện (2/15)
# Epoch 90/100 | LR: 0.000038 | Train Loss: 0.1505 | Val Score: 0.8685
#   => Mô hình tốt nhất! (Val Score: 0.8685)
# Epoch 91/100 | LR: 0.000031 | Train Loss: 0.1486 | Val Score: 0.8643
#   => Mô hình tốt nhất! (Val Score: 0.8643)
# Epoch 92/100 | LR: 0.000024 | Train Loss: 0.1467 | Val Score: 0.8612
#   => Mô hình tốt nhất! (Val Score: 0.8612)
# Epoch 93/100 | LR: 0.000019 | Train Loss: 0.1468 | Val Score: 0.8597
#   => Mô hình tốt nhất! (Val Score: 0.8597)
# Epoch 94/100 | LR: 0.000014 | Train Loss: 0.1484 | Val Score: 0.8628
#   => Mô hình không cải thiện (1/15)
# Epoch 95/100 | LR: 0.000010 | Train Loss: 0.1487 | Val Score: 0.8636
#   => Mô hình không cải thiện (2/15)
# Epoch 96/100 | LR: 0.000006 | Train Loss: 0.1512 | Val Score: 0.8655
#   => Mô hình không cải thiện (3/15)
# Epoch 97/100 | LR: 0.000003 | Train Loss: 0.1470 | Val Score: 0.8655
#   => Mô hình không cải thiện (4/15)
# Epoch 98/100 | LR: 0.000002 | Train Loss: 0.1468 | Val Score: 0.8655
#   => Mô hình không cải thiện (5/15)
# Epoch 99/100 | LR: 0.000000 | Train Loss: 0.1480 | Val Score: 0.8657
#   => Mô hình không cải thiện (6/15)
# Epoch 100/100 | LR: 0.000000 | Train Loss: 0.1491 | Val Score: 0.8657
#   => Mô hình không cải thiện (7/15)
#
# => ĐÃ KHÓA ĐƯỢC BEST EPOCH TẠI VÒNG: 93
#
# ============================================================================
# THUỘC TÍNH   | MAE        | MSE          | RMSE       | WMAPE
# ----------------------------------------------------------------------------
# Attr 1       | 0.8870     | 2.4298       | 1.5588     | 13.2469
# Attr 2       | 1.7361     | 10.8215      | 3.2896     | 13.6195
# Attr 3       | 1.7308     | 34.7926      | 5.8985     | 3.4829
# Attr 4       | 0.9881     | 3.0119       | 1.7355     | 14.7625
# Attr 5       | 2.2979     | 18.1420      | 4.2593     | 17.2096
# Attr 6       | 1.9543     | 42.8076      | 6.5428     | 3.9267
# ============================================================================
# MAE            : 1.5990
# MSE            : 18.6676
# RMSE           : 4.3206
# WMAPE          : 6.9046
# WMSE           : 0.8597
# ============================================================================

# %%
print("--- CHUẨN BỊ FULL DATA (TRAIN + VAL) ---")
x_full = pd.concat([x_train, x_val], ignore_index=True)
y_full = pd.concat([y_train, y_val], ignore_index=True)

full_dataset = UserBehaviorDataset(x_full, y_full, augment=True)
full_loader = DataLoader(
    full_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=True, 
    num_workers=2, 
    worker_init_fn=seed_worker, 
    generator=data_generator,
    pin_memory=True, 
    drop_last=True, 
    persistent_workers=True  
)
# Out:
# --- CHUẨN BỊ FULL DATA (TRAIN + VAL) ---

# %%
retrain_epochs = int(best_epoch * 1.1) 
if retrain_epochs < 1: retrain_epochs = 1
print(f"Bắt đầu retrain toàn diện với {retrain_epochs} epochs...")

retrained_model = AdvancedTARNet(vocab_size=VOCAB_SIZE).to(DEVICE)
retrain_optimizer = optim.AdamW(retrained_model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
retrain_scheduler = optim.lr_scheduler.OneCycleLR(
    retrain_optimizer, max_lr=MAX_LR, epochs=retrain_epochs, 
    steps_per_epoch=len(full_loader), pct_start=PCT_START, final_div_factor=FINAL_DIV_FACTOR
)

loss_fn = HybridThresholdLoss(DEVICE)
scaler = GradScaler()

retrained_model.train()
for epoch in range(retrain_epochs):
    if epoch <= 10:
        loss_fn.update_params(epoch) 
        
    train_loss = 0.0
    for x, y in full_loader:
        x, y = x.to(DEVICE), y.to(DEVICE)
        retrain_optimizer.zero_grad(set_to_none=True)
        
        with autocast():
            preds = retrained_model(x)
            
        loss = loss_fn(preds, y.float())
        scaler.scale(loss).backward()
        scaler.unscale_(retrain_optimizer)
        torch.nn.utils.clip_grad_norm_(retrained_model.parameters(), max_norm=1.0)
        scaler.step(retrain_optimizer)
        scaler.update()
        retrain_scheduler.step()
        train_loss += loss.item()
        
    avg_train_loss = train_loss / len(full_loader)
    print(f"Retrain Epoch {epoch + 1:02d}/{retrain_epochs} | LR: {retrain_optimizer.param_groups[0]['lr']:.6f} | Train Loss: {avg_train_loss:.4f}")

RETRAIN_CHECKPOINT = CHECKPOINT_FILE.replace(".pth", "_retrained.pth")
torch.save(retrained_model.state_dict(), RETRAIN_CHECKPOINT)
print(f"\n=> Đã lưu mô hình retrain tại: {RETRAIN_CHECKPOINT}")
# Out:
# Bắt đầu retrain toàn diện với 102 epochs...
# Retrain Epoch 01/102 | LR: 0.000046 | Train Loss: 1.6413
# Retrain Epoch 02/102 | LR: 0.000063 | Train Loss: 1.7148
# Retrain Epoch 03/102 | LR: 0.000090 | Train Loss: 1.8679
# Retrain Epoch 04/102 | LR: 0.000128 | Train Loss: 1.9233
# Retrain Epoch 05/102 | LR: 0.000175 | Train Loss: 1.6708
# Retrain Epoch 06/102 | LR: 0.000231 | Train Loss: 1.5333
# Retrain Epoch 07/102 | LR: 0.000293 | Train Loss: 1.3852
# Retrain Epoch 08/102 | LR: 0.000361 | Train Loss: 1.0485
# Retrain Epoch 09/102 | LR: 0.000432 | Train Loss: 0.7901
# Retrain Epoch 10/102 | LR: 0.000505 | Train Loss: 0.5975
# Retrain Epoch 11/102 | LR: 0.000579 | Train Loss: 0.4225
# Retrain Epoch 12/102 | LR: 0.000652 | Train Loss: 0.3911
# Retrain Epoch 13/102 | LR: 0.000721 | Train Loss: 0.3680
# Retrain Epoch 14/102 | LR: 0.000785 | Train Loss: 0.3498
# Retrain Epoch 15/102 | LR: 0.000844 | Train Loss: 0.3321
# Retrain Epoch 16/102 | LR: 0.000894 | Train Loss: 0.3202
# Retrain Epoch 17/102 | LR: 0.000936 | Train Loss: 0.3051
# Retrain Epoch 18/102 | LR: 0.000968 | Train Loss: 0.2857
# Retrain Epoch 19/102 | LR: 0.000989 | Train Loss: 0.2710
# Retrain Epoch 20/102 | LR: 0.000999 | Train Loss: 0.2667
# Retrain Epoch 21/102 | LR: 0.001000 | Train Loss: 0.2613
# Retrain Epoch 22/102 | LR: 0.000999 | Train Loss: 0.2539
# Retrain Epoch 23/102 | LR: 0.000997 | Train Loss: 0.2462
# Retrain Epoch 24/102 | LR: 0.000995 | Train Loss: 0.2413
# Retrain Epoch 25/102 | LR: 0.000992 | Train Loss: 0.2367
# Retrain Epoch 26/102 | LR: 0.000988 | Train Loss: 0.2339
# Retrain Epoch 27/102 | LR: 0.000984 | Train Loss: 0.2281
# Retrain Epoch 28/102 | LR: 0.000979 | Train Loss: 0.2265
# Retrain Epoch 29/102 | LR: 0.000973 | Train Loss: 0.2260
# Retrain Epoch 30/102 | LR: 0.000966 | Train Loss: 0.2213
# Retrain Epoch 31/102 | LR: 0.000959 | Train Loss: 0.2198
# Retrain Epoch 32/102 | LR: 0.000951 | Train Loss: 0.2168
# Retrain Epoch 33/102 | LR: 0.000942 | Train Loss: 0.2146
# Retrain Epoch 34/102 | LR: 0.000933 | Train Loss: 0.2115
# Retrain Epoch 35/102 | LR: 0.000923 | Train Loss: 0.2136
# Retrain Epoch 36/102 | LR: 0.000912 | Train Loss: 0.2080
# Retrain Epoch 37/102 | LR: 0.000901 | Train Loss: 0.2077
# Retrain Epoch 38/102 | LR: 0.000889 | Train Loss: 0.2052
# Retrain Epoch 39/102 | LR: 0.000877 | Train Loss: 0.2061
# Retrain Epoch 40/102 | LR: 0.000864 | Train Loss: 0.2037
# Retrain Epoch 41/102 | LR: 0.000851 | Train Loss: 0.2014
# Retrain Epoch 42/102 | LR: 0.000837 | Train Loss: 0.2036
# Retrain Epoch 43/102 | LR: 0.000822 | Train Loss: 0.2009
# Retrain Epoch 44/102 | LR: 0.000807 | Train Loss: 0.1998
# Retrain Epoch 45/102 | LR: 0.000792 | Train Loss: 0.1958
# Retrain Epoch 46/102 | LR: 0.000776 | Train Loss: 0.1946
# Retrain Epoch 47/102 | LR: 0.000760 | Train Loss: 0.1937
# Retrain Epoch 48/102 | LR: 0.000743 | Train Loss: 0.1937
# Retrain Epoch 49/102 | LR: 0.000726 | Train Loss: 0.1905
# Retrain Epoch 50/102 | LR: 0.000709 | Train Loss: 0.1878
# Retrain Epoch 51/102 | LR: 0.000691 | Train Loss: 0.1909
# Retrain Epoch 52/102 | LR: 0.000673 | Train Loss: 0.1889
# Retrain Epoch 53/102 | LR: 0.000655 | Train Loss: 0.1872
# Retrain Epoch 54/102 | LR: 0.000637 | Train Loss: 0.1882
# Retrain Epoch 55/102 | LR: 0.000618 | Train Loss: 0.1855
# Retrain Epoch 56/102 | LR: 0.000599 | Train Loss: 0.1811
# Retrain Epoch 57/102 | LR: 0.000580 | Train Loss: 0.1820
# Retrain Epoch 58/102 | LR: 0.000561 | Train Loss: 0.1815
# Retrain Epoch 59/102 | LR: 0.000542 | Train Loss: 0.1809
# Retrain Epoch 60/102 | LR: 0.000523 | Train Loss: 0.1795
# Retrain Epoch 61/102 | LR: 0.000504 | Train Loss: 0.1797
# Retrain Epoch 62/102 | LR: 0.000484 | Train Loss: 0.1765
# Retrain Epoch 63/102 | LR: 0.000465 | Train Loss: 0.1785
# Retrain Epoch 64/102 | LR: 0.000446 | Train Loss: 0.1766
# Retrain Epoch 65/102 | LR: 0.000427 | Train Loss: 0.1737
# Retrain Epoch 66/102 | LR: 0.000408 | Train Loss: 0.1756
# Retrain Epoch 67/102 | LR: 0.000389 | Train Loss: 0.1775
# Retrain Epoch 68/102 | LR: 0.000370 | Train Loss: 0.1745
# Retrain Epoch 69/102 | LR: 0.000352 | Train Loss: 0.1743
# Retrain Epoch 70/102 | LR: 0.000334 | Train Loss: 0.1711
# Retrain Epoch 71/102 | LR: 0.000316 | Train Loss: 0.1741
# Retrain Epoch 72/102 | LR: 0.000298 | Train Loss: 0.1711
# Retrain Epoch 73/102 | LR: 0.000280 | Train Loss: 0.1710
# Retrain Epoch 74/102 | LR: 0.000263 | Train Loss: 0.1715
# Retrain Epoch 75/102 | LR: 0.000247 | Train Loss: 0.1674
# Retrain Epoch 76/102 | LR: 0.000230 | Train Loss: 0.1696
# Retrain Epoch 77/102 | LR: 0.000214 | Train Loss: 0.1690
# Retrain Epoch 78/102 | LR: 0.000199 | Train Loss: 0.1687
# Retrain Epoch 79/102 | LR: 0.000183 | Train Loss: 0.1670
# Retrain Epoch 80/102 | LR: 0.000169 | Train Loss: 0.1682
# Retrain Epoch 81/102 | LR: 0.000155 | Train Loss: 0.1694
# Retrain Epoch 82/102 | LR: 0.000141 | Train Loss: 0.1650
# Retrain Epoch 83/102 | LR: 0.000128 | Train Loss: 0.1682
# Retrain Epoch 84/102 | LR: 0.000115 | Train Loss: 0.1658
# Retrain Epoch 85/102 | LR: 0.000103 | Train Loss: 0.1639
# Retrain Epoch 86/102 | LR: 0.000092 | Train Loss: 0.1651
# Retrain Epoch 87/102 | LR: 0.000081 | Train Loss: 0.1666
# Retrain Epoch 88/102 | LR: 0.000071 | Train Loss: 0.1639
# Retrain Epoch 89/102 | LR: 0.000061 | Train Loss: 0.1640
# Retrain Epoch 90/102 | LR: 0.000052 | Train Loss: 0.1618
# Retrain Epoch 91/102 | LR: 0.000044 | Train Loss: 0.1651
# Retrain Epoch 92/102 | LR: 0.000037 | Train Loss: 0.1652
# Retrain Epoch 93/102 | LR: 0.000030 | Train Loss: 0.1639
# Retrain Epoch 94/102 | LR: 0.000023 | Train Loss: 0.1628
# Retrain Epoch 95/102 | LR: 0.000018 | Train Loss: 0.1632
# Retrain Epoch 96/102 | LR: 0.000013 | Train Loss: 0.1641
# Retrain Epoch 97/102 | LR: 0.000009 | Train Loss: 0.1644
# Retrain Epoch 98/102 | LR: 0.000006 | Train Loss: 0.1636
# Retrain Epoch 99/102 | LR: 0.000003 | Train Loss: 0.1635
# Retrain Epoch 100/102 | LR: 0.000001 | Train Loss: 0.1605
# Retrain Epoch 101/102 | LR: 0.000000 | Train Loss: 0.1638
# Retrain Epoch 102/102 | LR: 0.000000 | Train Loss: 0.1626
#
# => Đã lưu mô hình retrain tại: /kaggle/working/best_model_retrained.pth

# %%
retrained_model.eval()
test_preds = run_inference(retrained_model, test_loader)
submission_df = pd.DataFrame({"id": x_test["id"]})

for idx, attr in enumerate(ATTRIBUTE_LIST):
    submission_df[f"attr_{attr}"] = test_preds[:, idx].astype(np.uint16)

submission_df.to_csv("submission_retrained.csv", index=False)
print("Đã xuất file submission_retrained.csv!")
# Out:
# Đã xuất file submission_retrained.csv!
